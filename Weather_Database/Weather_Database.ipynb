# %%
# Import the dependencies.
import pandas as pd
import gmaps
import numpy as np
import random
import sys
import requests
from citipy import citipy

sys.path.append('..')

# Import the API key.
from config import g_key
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
       
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Fill City Data list 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloud,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
       
    # If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | puerto varas
# Processing Record 5 of Set 1 | lugovoy
# Processing Record 6 of Set 1 | sobolevo
# Processing Record 7 of Set 1 | agsu
# 'sys'
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | polovinnoye
# Processing Record 13 of Set 1 | hofn
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | coquimbo
# Processing Record 18 of Set 1 | bahia honda
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | attawapiskat
# 'sys'
# Processing Record 21 of Set 1 | bharatpur
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | egvekinot
# Processing Record 24 of Set 1 | ballina
# Processing Record 25 of Set 1 | bandarbeyla
# Processing Record 26 of Set 1 | broken hill
# Processing Record 27 of Set 1 | orotukan
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | cayenne
# Processing Record 30 of Set 1 | hualmay
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | viligili
# 'sys'
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | mys shmidta
# 'sys'
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | dholka
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | tuatapere
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | qui nhon
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | katsuura
# Processing Record 50 of Set 1 | urdzhar
# 'sys'
# Processing Record 1 of Set 2 | gornozavodsk
# Processing Record 2 of Set 2 | taolanaro
# 'sys'
# Processing Record 3 of Set 2 | lompoc
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | sanghar
# Processing Record 6 of Set 2 | araouane
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | iroquois falls
# Processing Record 9 of Set 2 | huarmey
# Processing Record 10 of Set 2 | touros
# Processing Record 11 of Set 2 | tsihombe
# 'sys'
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | puerto leguizamo
# Processing Record 15 of Set 2 | oistins
# Processing Record 16 of Set 2 | zhangye
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | marinette
# Processing Record 19 of Set 2 | lasa
# Processing Record 20 of Set 2 | te anau
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | samusu
# 'sys'
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | henties bay
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | flin flon
# Processing Record 33 of Set 2 | antofagasta
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | jacqueville
# Processing Record 36 of Set 2 | morondava
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | sao raimundo nonato
# Processing Record 39 of Set 2 | ko samui
# Processing Record 40 of Set 2 | la ronge
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | amderma
# 'sys'
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | vestmanna
# Processing Record 46 of Set 2 | palmer
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | galiwinku
# 'sys'
# Processing Record 49 of Set 2 | carsamba
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | shenjiamen
# Processing Record 2 of Set 3 | sisimiut
# Processing Record 3 of Set 3 | jardim
# Processing Record 4 of Set 3 | ndele
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | gurgan
# 'sys'
# Processing Record 8 of Set 3 | karera
# Processing Record 9 of Set 3 | plover
# Processing Record 10 of Set 3 | neryungri
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | jiayuguan
# Processing Record 13 of Set 3 | tateyama
# Processing Record 14 of Set 3 | tilichiki
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | andenes
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | luklukan
# Processing Record 20 of Set 3 | vanimo
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | sawtell
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | muli
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | palabuhanratu
# 'sys'
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | mocuba
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | norre alslev
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | haines junction
# Processing Record 36 of Set 3 | bara
# Processing Record 37 of Set 3 | dhandhuka
# Processing Record 38 of Set 3 | robertsport
# Processing Record 39 of Set 3 | barentsburg
# 'sys'
# Processing Record 40 of Set 3 | khamamatyurt
# Processing Record 41 of Set 3 | jinchang
# Processing Record 42 of Set 3 | rio grande
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | riyadh
# Processing Record 45 of Set 3 | korem
# Processing Record 46 of Set 3 | la macarena
# Processing Record 47 of Set 3 | poso
# Processing Record 48 of Set 3 | kerrville
# Processing Record 49 of Set 3 | mantua
# Processing Record 50 of Set 3 | fare
# Processing Record 1 of Set 4 | kibala
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | abatskoye
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | bonavista
# Processing Record 6 of Set 4 | port hedland
# Processing Record 7 of Set 4 | faya
# Processing Record 8 of Set 4 | sao gabriel da cachoeira
# Processing Record 9 of Set 4 | solnechnyy
# Processing Record 10 of Set 4 | adrar
# Processing Record 11 of Set 4 | afua
# Processing Record 12 of Set 4 | adeje
# Processing Record 13 of Set 4 | nemuro
# Processing Record 14 of Set 4 | porto walter
# Processing Record 15 of Set 4 | bargal
# 'sys'
# Processing Record 16 of Set 4 | coolum beach
# Processing Record 17 of Set 4 | cochabamba
# Processing Record 18 of Set 4 | sorland
# Processing Record 19 of Set 4 | adrano
# Processing Record 20 of Set 4 | usinsk
# Processing Record 21 of Set 4 | marcona
# 'sys'
# Processing Record 22 of Set 4 | krasnyy chikoy
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | loubomo
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | marovoay
# Processing Record 29 of Set 4 | rawson
# Processing Record 30 of Set 4 | ketchikan
# Processing Record 31 of Set 4 | jalu
# Processing Record 32 of Set 4 | beloha
# Processing Record 33 of Set 4 | port blair
# Processing Record 34 of Set 4 | yumen
# Processing Record 35 of Set 4 | labytnangi
# Processing Record 36 of Set 4 | hirara
# Processing Record 37 of Set 4 | port-cartier
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | prince rupert
# Processing Record 40 of Set 4 | cabedelo
# Processing Record 41 of Set 4 | pampa
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | bambanglipuro
# Processing Record 44 of Set 4 | san quintin
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | khasan
# Processing Record 47 of Set 4 | whitehorse
# Processing Record 48 of Set 4 | santander
# Processing Record 49 of Set 4 | illoqqortoormiut
# 'sys'
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | de-kastri
# Processing Record 3 of Set 5 | butaritari
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | white rock
# Processing Record 6 of Set 5 | anqing
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | dhidhdhoo
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | sharjah
# Processing Record 11 of Set 5 | bastia
# Processing Record 12 of Set 5 | popondetta
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | sete
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | berlevag
# Processing Record 18 of Set 5 | mount gambier
# Processing Record 19 of Set 5 | belushya guba
# 'sys'
# Processing Record 20 of Set 5 | benjamin constant
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | puerto suarez
# Processing Record 23 of Set 5 | nagato
# Processing Record 24 of Set 5 | rincon
# Processing Record 25 of Set 5 | karratha
# Processing Record 26 of Set 5 | skegness
# Processing Record 27 of Set 5 | manali
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | srednekolymsk
# Processing Record 32 of Set 5 | douglas
# Processing Record 33 of Set 5 | montepuez
# Processing Record 34 of Set 5 | nobeoka
# Processing Record 35 of Set 5 | syumsi
# Processing Record 36 of Set 5 | bocas del toro
# Processing Record 37 of Set 5 | vostok
# Processing Record 38 of Set 5 | tromso
# Processing Record 39 of Set 5 | gagra
# Processing Record 40 of Set 5 | batagay-alyta
# Processing Record 41 of Set 5 | ramshir
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | wau
# Processing Record 44 of Set 5 | puerto baquerizo moreno
# Processing Record 45 of Set 5 | hastings
# Processing Record 46 of Set 5 | bac lieu
# Processing Record 47 of Set 5 | vila
# Processing Record 48 of Set 5 | lerwick
# Processing Record 49 of Set 5 | kargasok
# Processing Record 50 of Set 5 | labuan
# Processing Record 1 of Set 6 | nizhneyansk
# 'sys'
# Processing Record 2 of Set 6 | hamilton
# Processing Record 3 of Set 6 | naze
# Processing Record 4 of Set 6 | viedma
# Processing Record 5 of Set 6 | tunduru
# 'sys'
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | pacific grove
# Processing Record 8 of Set 6 | yongzhou
# Processing Record 9 of Set 6 | yar-sale
# Processing Record 10 of Set 6 | saint anthony
# Processing Record 11 of Set 6 | grand river south east
# 'sys'
# Processing Record 12 of Set 6 | tairua
# Processing Record 13 of Set 6 | sept-iles
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | villa maria
# Processing Record 16 of Set 6 | ati
# Processing Record 17 of Set 6 | itarema
# Processing Record 18 of Set 6 | akdepe
# Processing Record 19 of Set 6 | mastic beach
# Processing Record 20 of Set 6 | moose factory
# Processing Record 21 of Set 6 | zhezkazgan
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | dongying
# Processing Record 24 of Set 6 | rungata
# 'sys'
# Processing Record 25 of Set 6 | manoharpur
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | chicama
# Processing Record 28 of Set 6 | maunabo
# Processing Record 29 of Set 6 | kot diji
# Processing Record 30 of Set 6 | kedougou
# Processing Record 31 of Set 6 | pasaje
# Processing Record 32 of Set 6 | walla walla
# Processing Record 33 of Set 6 | darhan
# Processing Record 34 of Set 6 | dubai
# Processing Record 35 of Set 6 | archidona
# Processing Record 36 of Set 6 | shimoda
# Processing Record 37 of Set 6 | binga
# Processing Record 38 of Set 6 | shache
# Processing Record 39 of Set 6 | gazanjyk
# Processing Record 40 of Set 6 | gudalur
# Processing Record 41 of Set 6 | auraiya
# Processing Record 42 of Set 6 | doha
# Processing Record 43 of Set 6 | vilyuysk
# Processing Record 44 of Set 6 | bosaso
# Processing Record 45 of Set 6 | littleton
# Processing Record 46 of Set 6 | kieta
# Processing Record 47 of Set 6 | port augusta
# Processing Record 48 of Set 6 | warri
# Processing Record 49 of Set 6 | severobaykalsk
# Processing Record 50 of Set 6 | karaul
# 'sys'
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | quartucciu
# Processing Record 3 of Set 7 | dicabisagan
# Processing Record 4 of Set 7 | warburton
# Processing Record 5 of Set 7 | nouadhibou
# Processing Record 6 of Set 7 | niono
# Processing Record 7 of Set 7 | kyshtovka
# Processing Record 8 of Set 7 | zanzibar
# Processing Record 9 of Set 7 | puerto narino
# Processing Record 10 of Set 7 | ponta delgada
# Processing Record 11 of Set 7 | airai
# Processing Record 12 of Set 7 | fergus falls
# Processing Record 13 of Set 7 | bacolod
# Processing Record 14 of Set 7 | christchurch
# Processing Record 15 of Set 7 | mount isa
# Processing Record 16 of Set 7 | pleasant point
# Processing Record 17 of Set 7 | kysyl-syr
# Processing Record 18 of Set 7 | mayo
# Processing Record 19 of Set 7 | raduzhnyy
# Processing Record 20 of Set 7 | kanniyakumari
# Processing Record 21 of Set 7 | arlit
# Processing Record 22 of Set 7 | gilgit
# Processing Record 23 of Set 7 | hovd
# Processing Record 24 of Set 7 | victor harbor
# Processing Record 25 of Set 7 | ahipara
# Processing Record 26 of Set 7 | jining
# Processing Record 27 of Set 7 | ornskoldsvik
# Processing Record 28 of Set 7 | phan rang
# 'sys'
# Processing Record 29 of Set 7 | mahajanga
# Processing Record 30 of Set 7 | bowen
# Processing Record 31 of Set 7 | reggio di calabria
# Processing Record 32 of Set 7 | itoman
# Processing Record 33 of Set 7 | huilong
# Processing Record 34 of Set 7 | rasshevatskaya
# Processing Record 35 of Set 7 | ishigaki
# Processing Record 36 of Set 7 | gushikawa
# Processing Record 37 of Set 7 | sindand
# 'sys'
# Processing Record 38 of Set 7 | salinas
# Processing Record 39 of Set 7 | bahir dar
# Processing Record 40 of Set 7 | ulaanbaatar
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | avera
# Processing Record 43 of Set 7 | nedjo
# Processing Record 44 of Set 7 | oakdale
# Processing Record 45 of Set 7 | marrakesh
# Processing Record 46 of Set 7 | kumbhraj
# Processing Record 47 of Set 7 | graham
# Processing Record 48 of Set 7 | tupelo
# Processing Record 49 of Set 7 | mar del plata
# Processing Record 50 of Set 7 | vila velha
# Processing Record 1 of Set 8 | cairns
# Processing Record 2 of Set 8 | careiro da varzea
# Processing Record 3 of Set 8 | toora-khem
# Processing Record 4 of Set 8 | komsomolskiy
# Processing Record 5 of Set 8 | binzhou
# Processing Record 6 of Set 8 | sao joao da barra
# Processing Record 7 of Set 8 | sentyabrskiy
# 'sys'
# Processing Record 8 of Set 8 | pochutla
# Processing Record 9 of Set 8 | fuling
# Processing Record 10 of Set 8 | wenatchee
# Processing Record 11 of Set 8 | derzhavinsk
# Processing Record 12 of Set 8 | gat
# Processing Record 13 of Set 8 | talakan
# Processing Record 14 of Set 8 | georgetown
# Processing Record 15 of Set 8 | umm kaddadah
# Processing Record 16 of Set 8 | kirkuk
# Processing Record 17 of Set 8 | sahrak
# 'sys'
# Processing Record 18 of Set 8 | nassjo
# Processing Record 19 of Set 8 | kathmandu
# Processing Record 20 of Set 8 | sakakah
# Processing Record 21 of Set 8 | madison
# Processing Record 22 of Set 8 | aromashevo
# Processing Record 23 of Set 8 | brejo
# Processing Record 24 of Set 8 | novoagansk
# Processing Record 25 of Set 8 | boa vista
# Processing Record 26 of Set 8 | pembroke
# Processing Record 27 of Set 8 | vagay
# Processing Record 28 of Set 8 | iracoubo
# Processing Record 29 of Set 8 | brae
# Processing Record 30 of Set 8 | novyy svit
# Processing Record 31 of Set 8 | roscommon
# Processing Record 32 of Set 8 | bethel
# Processing Record 33 of Set 8 | dudinka
# Processing Record 34 of Set 8 | maceio
# Processing Record 35 of Set 8 | ushtobe
# Processing Record 36 of Set 8 | ust-nera
# Processing Record 37 of Set 8 | ostrovnoy
# Processing Record 38 of Set 8 | najran
# Processing Record 39 of Set 8 | salalah
# Processing Record 40 of Set 8 | lazarev
# Processing Record 41 of Set 8 | labrea
# Processing Record 42 of Set 8 | vaitupu
# 'sys'
# Processing Record 43 of Set 8 | iseyin
# Processing Record 44 of Set 8 | soyo
# Processing Record 45 of Set 8 | ulladulla
# Processing Record 46 of Set 8 | bengkulu
# Processing Record 47 of Set 8 | saskylakh
# Processing Record 48 of Set 8 | leiyang
# Processing Record 49 of Set 8 | saldanha
# Processing Record 50 of Set 8 | kundiawa
# Processing Record 1 of Set 9 | sorvag
# 'sys'
# Processing Record 2 of Set 9 | kuala terengganu
# Processing Record 3 of Set 9 | taoudenni
# Processing Record 4 of Set 9 | kargopol
# Processing Record 5 of Set 9 | kudahuvadhoo
# Processing Record 6 of Set 9 | inhambane
# Processing Record 7 of Set 9 | coos bay
# Processing Record 8 of Set 9 | ampanihy
# Processing Record 9 of Set 9 | umm lajj
# Processing Record 10 of Set 9 | ust-maya
# Processing Record 11 of Set 9 | praia da vitoria
# Processing Record 12 of Set 9 | turkan
# Processing Record 13 of Set 9 | santa cruz de tenerife
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | lovozero
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | xalpatlahuac
# Processing Record 18 of Set 9 | kalabo
# Processing Record 19 of Set 9 | douentza
# Processing Record 20 of Set 9 | port hardy
# Processing Record 21 of Set 9 | malente
# Processing Record 22 of Set 9 | hunza
# 'sys'
# Processing Record 23 of Set 9 | kibakwe
# Processing Record 24 of Set 9 | leningradskiy
# Processing Record 25 of Set 9 | kaliganj
# Processing Record 26 of Set 9 | davila
# Processing Record 27 of Set 9 | monrovia
# Processing Record 28 of Set 9 | mogzon
# Processing Record 29 of Set 9 | margate
# Processing Record 30 of Set 9 | curaca
# Processing Record 31 of Set 9 | kerema
# Processing Record 32 of Set 9 | baykit
# Processing Record 33 of Set 9 | burgeo
# Processing Record 34 of Set 9 | arraias
# Processing Record 35 of Set 9 | lunenburg
# Processing Record 36 of Set 9 | otavi
# Processing Record 37 of Set 9 | baracoa
# Processing Record 38 of Set 9 | san lawrenz
# Processing Record 39 of Set 9 | omsukchan
# Processing Record 40 of Set 9 | schneverdingen
# Processing Record 41 of Set 9 | college
# Processing Record 42 of Set 9 | east london
# Processing Record 43 of Set 9 | sesheke
# Processing Record 44 of Set 9 | abeche
# Processing Record 45 of Set 9 | laguna
# Processing Record 46 of Set 9 | nisia floresta
# Processing Record 47 of Set 9 | maniitsoq
# Processing Record 48 of Set 9 | locri
# Processing Record 49 of Set 9 | saint-louis
# Processing Record 50 of Set 9 | dunedin
# Processing Record 1 of Set 10 | belaya gora
# Processing Record 2 of Set 10 | baie-comeau
# Processing Record 3 of Set 10 | kailua
# Processing Record 4 of Set 10 | lima
# Processing Record 5 of Set 10 | yuryuzan
# Processing Record 6 of Set 10 | bellefontaine
# Processing Record 7 of Set 10 | bintulu
# Processing Record 8 of Set 10 | kanye
# Processing Record 9 of Set 10 | olafsvik
# Processing Record 10 of Set 10 | nicoya
# Processing Record 11 of Set 10 | lata
# Processing Record 12 of Set 10 | lorengau
# Processing Record 13 of Set 10 | kamenskoye
# 'sys'
# Processing Record 14 of Set 10 | bubaque
# Processing Record 15 of Set 10 | guiratinga
# Processing Record 16 of Set 10 | chapais
# Processing Record 17 of Set 10 | phangnga
# Processing Record 18 of Set 10 | nhulunbuy
# Processing Record 19 of Set 10 | batemans bay
# Processing Record 20 of Set 10 | amherst
# Processing Record 21 of Set 10 | mananjary
# Processing Record 22 of Set 10 | kupino
# Processing Record 23 of Set 10 | candawaga
# 'sys'
# Processing Record 24 of Set 10 | encruzilhada do sul
# Processing Record 25 of Set 10 | kisangani
# Processing Record 26 of Set 10 | katherine
# Processing Record 27 of Set 10 | port moresby
# Processing Record 28 of Set 10 | jaque
# Processing Record 29 of Set 10 | sola
# Processing Record 30 of Set 10 | baneh
# Processing Record 31 of Set 10 | surgut
# Processing Record 32 of Set 10 | robe
# Processing Record 33 of Set 10 | port-gentil
# Processing Record 34 of Set 10 | manacapuru
# Processing Record 35 of Set 10 | norman wells
# Processing Record 36 of Set 10 | veraval
# Processing Record 37 of Set 10 | lago da pedra
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | mount pleasant
# Processing Record 40 of Set 10 | kholmsk
# Processing Record 41 of Set 10 | salinopolis
# Processing Record 42 of Set 10 | myitkyina
# Processing Record 43 of Set 10 | kahului
# Processing Record 44 of Set 10 | bolshaya murta
# 'sys'
# Processing Record 45 of Set 10 | sao filipe
# Processing Record 46 of Set 10 | yamethin
# Processing Record 47 of Set 10 | turukhansk
# Processing Record 48 of Set 10 | sinnamary
# Processing Record 49 of Set 10 | manaquiri
# Processing Record 50 of Set 10 | ravensburg
# Processing Record 1 of Set 11 | muros
# Processing Record 2 of Set 11 | hervey bay
# Processing Record 3 of Set 11 | sassandra
# Processing Record 4 of Set 11 | assiniboia
# Processing Record 5 of Set 11 | sao domingos
# Processing Record 6 of Set 11 | poronaysk
# Processing Record 7 of Set 11 | petropavlovka
# Processing Record 8 of Set 11 | tsabong
# Processing Record 9 of Set 11 | hasaki
# Processing Record 10 of Set 11 | nelidovo
# Processing Record 11 of Set 11 | poum
# Processing Record 12 of Set 11 | beziers
# Processing Record 13 of Set 11 | tonj
# Processing Record 14 of Set 11 | felidhoo
# 'sys'
# Processing Record 15 of Set 11 | eyl
# Processing Record 16 of Set 11 | cabinda
# Processing Record 17 of Set 11 | tura
# Processing Record 18 of Set 11 | tidore
# 'sys'
# Processing Record 19 of Set 11 | jinsha
# Processing Record 20 of Set 11 | xining
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | xingyi
# Processing Record 23 of Set 11 | mongomo
# Processing Record 24 of Set 11 | altay
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | virginia beach
# Processing Record 27 of Set 11 | svetlogorsk
# Processing Record 28 of Set 11 | baoning
# Processing Record 29 of Set 11 | sydney
# Processing Record 30 of Set 11 | pimentel
# Processing Record 31 of Set 11 | south lake tahoe
# Processing Record 32 of Set 11 | yerofey pavlovich
# Processing Record 33 of Set 11 | eirunepe
# Processing Record 34 of Set 11 | jodar
# Processing Record 35 of Set 11 | kamwenge
# Processing Record 36 of Set 11 | dali
# Processing Record 37 of Set 11 | marietta
# Processing Record 38 of Set 11 | grand gaube
# Processing Record 39 of Set 11 | catamarca
# Processing Record 40 of Set 11 | nagua
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | gamba
# Processing Record 43 of Set 11 | fethiye
# Processing Record 44 of Set 11 | ximei
# Processing Record 45 of Set 11 | lawton
# Processing Record 46 of Set 11 | bajil
# Processing Record 47 of Set 11 | ugoofaaru
# Processing Record 48 of Set 11 | ribita
# Processing Record 49 of Set 11 | nantucket
# Processing Record 50 of Set 11 | campbell river
# Processing Record 1 of Set 12 | manila
# Processing Record 2 of Set 12 | la plata
# Processing Record 3 of Set 12 | tabuk
# Processing Record 4 of Set 12 | cockburn town
# Processing Record 5 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 12 | normandin
# Processing Record 7 of Set 12 | mana
# Processing Record 8 of Set 12 | cachira
# Processing Record 9 of Set 12 | vestmannaeyjar
# Processing Record 10 of Set 12 | saint-leu
# Processing Record 11 of Set 12 | waddan
# Processing Record 12 of Set 12 | qujing
# Processing Record 13 of Set 12 | saint-michel-des-saints
# Processing Record 14 of Set 12 | murray
# Processing Record 15 of Set 12 | ferry pass
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | kharp
# Processing Record 18 of Set 12 | longview
# Processing Record 19 of Set 12 | sivas
# Processing Record 20 of Set 12 | vanavara
# Processing Record 21 of Set 12 | comodoro rivadavia
# Processing Record 22 of Set 12 | narsaq
# Processing Record 23 of Set 12 | tessalit
# Processing Record 24 of Set 12 | verkhniy tagil
# Processing Record 25 of Set 12 | forestville
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | conakry
# Processing Record 28 of Set 12 | wuwei
# Processing Record 29 of Set 12 | samalaeulu
# 'sys'
# Processing Record 30 of Set 12 | dahra
# Processing Record 31 of Set 12 | codrington
# Processing Record 32 of Set 12 | basoko
# Processing Record 33 of Set 12 | floro
# Processing Record 34 of Set 12 | wajima
# Processing Record 35 of Set 12 | perigueux
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | nabire
# Processing Record 38 of Set 12 | usvyaty
# Processing Record 39 of Set 12 | huescar
# Processing Record 40 of Set 12 | shingu
# Processing Record 41 of Set 12 | honiara
# Processing Record 42 of Set 12 | dobryanka
# Processing Record 43 of Set 12 | puerto madero
# Processing Record 44 of Set 12 | honningsvag
# Processing Record 45 of Set 12 | tehachapi
# Processing Record 46 of Set 12 | richards bay
# Processing Record 47 of Set 12 | nome
# Processing Record 48 of Set 12 | kushmurun
# Processing Record 49 of Set 12 | umzimvubu
# 'sys'
# Processing Record 50 of Set 12 | lazaro cardenas
# Processing Record 1 of Set 13 | smithers
# Processing Record 2 of Set 13 | sambava
# Processing Record 3 of Set 13 | abha
# Processing Record 4 of Set 13 | tazmalt
# Processing Record 5 of Set 13 | grande prairie
# Processing Record 6 of Set 13 | darnah
# Processing Record 7 of Set 13 | san jose
# Processing Record 8 of Set 13 | sand
# Processing Record 9 of Set 13 | qaqortoq
# Processing Record 10 of Set 13 | san matias
# Processing Record 11 of Set 13 | madinat sittah uktubar
# Processing Record 12 of Set 13 | kushiro
# Processing Record 13 of Set 13 | kijang
# Processing Record 14 of Set 13 | lavrentiya
# Processing Record 15 of Set 13 | port lincoln
# Processing Record 16 of Set 13 | manta
# Processing Record 17 of Set 13 | kavaratti
# Processing Record 18 of Set 13 | zhigansk
# Processing Record 19 of Set 13 | buala
# Processing Record 20 of Set 13 | kaberamaido
# Processing Record 21 of Set 13 | skjervoy
# Processing Record 22 of Set 13 | letka
# Processing Record 23 of Set 13 | kamina
# Processing Record 24 of Set 13 | visnes
# Processing Record 25 of Set 13 | gao
# Processing Record 26 of Set 13 | preobrazheniye
# Processing Record 27 of Set 13 | puerto de la cruz
# Processing Record 28 of Set 13 | atar
# Processing Record 29 of Set 13 | khryashchevka
# Processing Record 30 of Set 13 | sulangan
# Processing Record 31 of Set 13 | camana
# Processing Record 32 of Set 13 | flinders
# Processing Record 33 of Set 13 | bonito
# Processing Record 34 of Set 13 | portland
# Processing Record 35 of Set 13 | bonfim
# Processing Record 36 of Set 13 | taitung
# Processing Record 37 of Set 13 | krasnoselkup
# Processing Record 38 of Set 13 | louisbourg
# 'sys'
# Processing Record 39 of Set 13 | hobyo
# Processing Record 40 of Set 13 | bida
# Processing Record 41 of Set 13 | nuuk
# Processing Record 42 of Set 13 | pocos de caldas
# Processing Record 43 of Set 13 | namatanai
# Processing Record 44 of Set 13 | zastavna
# Processing Record 45 of Set 13 | mirai
# Processing Record 46 of Set 13 | ancud
# Processing Record 47 of Set 13 | houma
# Processing Record 48 of Set 13 | mattoon
# Processing Record 49 of Set 13 | verkhnevilyuysk
# Processing Record 50 of Set 13 | masumbwe
# Processing Record 1 of Set 14 | aklavik
# Processing Record 2 of Set 14 | takoradi
# Processing Record 3 of Set 14 | yelan-koleno
# Processing Record 4 of Set 14 | dzhusaly
# 'sys'
# Processing Record 5 of Set 14 | siyabuswa
# Processing Record 6 of Set 14 | wadi maliz
# Processing Record 7 of Set 14 | rio cuarto
# Processing Record 8 of Set 14 | reinbek
# Processing Record 9 of Set 14 | daru
# Processing Record 10 of Set 14 | warrington
# Processing Record 11 of Set 14 | rio do sul
# Processing Record 12 of Set 14 | dien bien
# 'sys'
# Processing Record 13 of Set 14 | epe
# Processing Record 14 of Set 14 | jacareacanga
# Processing Record 15 of Set 14 | mecca
# Processing Record 16 of Set 14 | socorro
# Processing Record 17 of Set 14 | manado
# Processing Record 18 of Set 14 | alice springs
# Processing Record 19 of Set 14 | farmington
# Processing Record 20 of Set 14 | sandwick
# Processing Record 21 of Set 14 | vao
# Processing Record 22 of Set 14 | ngunguru
# Processing Record 23 of Set 14 | panalingaan
# Processing Record 24 of Set 14 | kalispell
# Processing Record 25 of Set 14 | kadaya
# Processing Record 26 of Set 14 | kazanskaya
# Processing Record 27 of Set 14 | opuwo
# Processing Record 28 of Set 14 | bulgan
# Processing Record 29 of Set 14 | muhos
# Processing Record 30 of Set 14 | zaysan
# Processing Record 31 of Set 14 | kuryk
# Processing Record 32 of Set 14 | umm durman
# 'sys'
# Processing Record 33 of Set 14 | romny
# Processing Record 34 of Set 14 | talah
# 'sys'
# Processing Record 35 of Set 14 | hof
# Processing Record 36 of Set 14 | galgani
# 'sys'
# Processing Record 37 of Set 14 | kemi
# Processing Record 38 of Set 14 | beringovskiy
# Processing Record 39 of Set 14 | kurumkan
# Processing Record 40 of Set 14 | barao de melgaco
# Processing Record 41 of Set 14 | skibbereen
# Processing Record 42 of Set 14 | kattivakkam
# Processing Record 43 of Set 14 | phu ly
# Processing Record 44 of Set 14 | half moon bay
# Processing Record 45 of Set 14 | inta
# Processing Record 46 of Set 14 | devonport
# Processing Record 47 of Set 14 | beeville
# Processing Record 48 of Set 14 | moranbah
# Processing Record 49 of Set 14 | general roca
# Processing Record 50 of Set 14 | utiroa
# 'sys'
# Processing Record 1 of Set 15 | quelimane
# Processing Record 2 of Set 15 | santo antonio do ica
# Processing Record 3 of Set 15 | ngukurr
# 'sys'
# Processing Record 4 of Set 15 | saint-francois
# Processing Record 5 of Set 15 | zolotkovo
# Processing Record 6 of Set 15 | trinidad
# Processing Record 7 of Set 15 | acarau
# Processing Record 8 of Set 15 | yelizovo
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | merced
# Processing Record 11 of Set 15 | sijunjung
# Processing Record 12 of Set 15 | carutapera
# Processing Record 13 of Set 15 | chernoyerkovskaya
# Processing Record 14 of Set 15 | tigil
# Processing Record 15 of Set 15 | necochea
# Processing Record 16 of Set 15 | etchoropo
# Processing Record 17 of Set 15 | almunecar
# Processing Record 18 of Set 15 | soe
# Processing Record 19 of Set 15 | bereda
# Processing Record 20 of Set 15 | shelburne
# Processing Record 21 of Set 15 | merauke
# Processing Record 22 of Set 15 | pyay
# Processing Record 23 of Set 15 | chambas
# Processing Record 24 of Set 15 | ambilobe
# Processing Record 25 of Set 15 | tsienyane
# 'sys'
# Processing Record 26 of Set 15 | saleaula
# 'sys'
# Processing Record 27 of Set 15 | malpe
# Processing Record 28 of Set 15 | smolenka
# Processing Record 29 of Set 15 | pangnirtung
# Processing Record 30 of Set 15 | saquarema
# Processing Record 31 of Set 15 | mandalgovi
# Processing Record 32 of Set 15 | aykhal
# Processing Record 33 of Set 15 | saint-joseph
# Processing Record 34 of Set 15 | formoso do araguaia
# 'sys'
# Processing Record 35 of Set 15 | saint-pierre
# Processing Record 36 of Set 15 | tapaua
# 'sys'
# Processing Record 37 of Set 15 | ola
# Processing Record 38 of Set 15 | constitucion
# Processing Record 39 of Set 15 | cozumel
# Processing Record 40 of Set 15 | padang
# Processing Record 41 of Set 15 | oriximina
# Processing Record 42 of Set 15 | kuytun
# Processing Record 43 of Set 15 | evensk
# Processing Record 44 of Set 15 | acapulco
# Processing Record 45 of Set 15 | huntington
# Processing Record 46 of Set 15 | antigonish
# Processing Record 47 of Set 15 | mizdah
# Processing Record 48 of Set 15 | wasilla
# Processing Record 49 of Set 15 | chabahar
# Processing Record 50 of Set 15 | bykovo
# Processing Record 1 of Set 16 | cotonou
# Processing Record 2 of Set 16 | obzor
# Processing Record 3 of Set 16 | cagayan de tawi-tawi
# 'sys'
# Processing Record 4 of Set 16 | sorong
# Processing Record 5 of Set 16 | llangefni
# Processing Record 6 of Set 16 | cumana
# Processing Record 7 of Set 16 | tumannyy
# 'sys'
# Processing Record 8 of Set 16 | gizo
# Processing Record 9 of Set 16 | sumbawa
# 'sys'
# Processing Record 10 of Set 16 | sechura
# Processing Record 11 of Set 16 | windhoek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Date': '2022-07-25 04:47:11',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.06,
#   'Humidity': 72,
#   'Cloudiness': 61,
#   'Wind Speed': 8.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Date': '2022-07-25 04:47:12',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 45.48,
#   'Humidity': 91,
#   'Cloudiness': 87,
#   'Wind Speed': 3.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:47:12',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 37.47,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Varas',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:47:13',
#   'Lat': -41.3195,
#   'Lng': -72.9854,
#   'Max Temp': 43.02,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'mist'},
#  {'City': 'Lugovoy',
#   'Country': 'KZ',
#   'Date': '2022-07-25 04:47:13',
#   'Lat': 42.9472,
#   'Lng': 72.7644,
#   'Max Temp': 90.32,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:14',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 60.21,
#   'Humidity': 92,
#   'Cloudiness': 29,
#   'Wind Speed': 8.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Date': '2022-07-25 04:47:14',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 56.71,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:44:26',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 48.9,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:46:16',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 35.71,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:47:15',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 58.86,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Polovinnoye',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:16',
#   'Lat': 54.7914,
#   'Lng': 65.9864,
#   'Max Temp': 75.58,
#   'Humidity': 56,
#   'Cloudiness': 8,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Date': '2022-07-25 04:47:16',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 49.71,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 6.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:16',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 65.44,
#   'Humidity': 35,
#   'Cloudiness': 27,
#   'Wind Speed': 8.28,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Date': '2022-07-25 04:44:13',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.25,
#   'Humidity': 81,
#   'Cloudiness': 15,
#   'Wind Speed': 18.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Date': '2022-07-25 04:45:33',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.55,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:43:21',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 53.33,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bahia Honda',
#   'Country': 'CU',
#   'Date': '2022-07-25 04:47:17',
#   'Lat': 22.9036,
#   'Lng': -83.1592,
#   'Max Temp': 77.99,
#   'Humidity': 88,
#   'Cloudiness': 44,
#   'Wind Speed': 10.25,
#   'Current Description': 'light rain'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Date': '2022-07-25 04:45:36',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 45.81,
#   'Humidity': 89,
#   'Cloudiness': 71,
#   'Wind Speed': 22.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bharatpur',
#   'Country': 'IN',
#   'Date': '2022-07-25 04:47:18',
#   'Lat': 27.2167,
#   'Lng': 77.4833,
#   'Max Temp': 92.64,
#   'Humidity': 52,
#   'Cloudiness': 16,
#   'Wind Speed': 12.64,
#   'Current Description': 'few clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Date': '2022-07-25 04:47:19',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 69.98,
#   'Humidity': 94,
#   'Cloudiness': 61,
#   'Wind Speed': 2.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:19',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 43.05,
#   'Humidity': 61,
#   'Cloudiness': 96,
#   'Wind Speed': 3.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:47:20',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 67.01,
#   'Humidity': 71,
#   'Cloudiness': 18,
#   'Wind Speed': 4.38,
#   'Current Description': 'few clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Date': '2022-07-25 04:47:20',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 81.41,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 30.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:47:21',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 66.11,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 15.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Orotukan',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:21',
#   'Lat': 62.2667,
#   'Lng': 151.7,
#   'Max Temp': 68.79,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 4.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:46:53',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 51.57,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 17.94,
#   'Current Description': 'light rain'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Date': '2022-07-25 04:45:41',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 82.09,
#   'Humidity': 1,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Date': '2022-07-25 04:47:22',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 61.14,
#   'Humidity': 87,
#   'Cloudiness': 55,
#   'Wind Speed': 10.87,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:45:42',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.55,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 14.65,
#   'Current Description': 'moderate rain'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Date': '2022-07-25 04:47:22',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.22,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:47:23',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 48.4,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Date': '2022-07-25 04:47:23',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 57.74,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Date': '2022-07-25 04:44:15',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:47:24',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 44.33,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:44:29',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 44.74,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Date': '2022-07-25 04:44:21',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 76.48,
#   'Humidity': 67,
#   'Cloudiness': 2,
#   'Wind Speed': 14.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:47:25',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 61.05,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 15.37,
#   'Current Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Date': '2022-07-25 04:45:43',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 55.92,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 2.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dholka',
#   'Country': 'IN',
#   'Date': '2022-07-25 04:47:26',
#   'Lat': 22.7167,
#   'Lng': 72.4667,
#   'Max Temp': 80.98,
#   'Humidity': 69,
#   'Cloudiness': 88,
#   'Wind Speed': 12.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:47:27',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 67.69,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 10.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Date': '2022-07-25 04:47:27',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 44.35,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 2.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Date': '2022-07-25 04:45:37',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 46.17,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 13.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qui Nhon',
#   'Country': 'VN',
#   'Date': '2022-07-25 04:47:28',
#   'Lat': 13.7667,
#   'Lng': 109.2333,
#   'Max Temp': 85.95,
#   'Humidity': 66,
#   'Cloudiness': 64,
#   'Wind Speed': 8.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:44:28',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 51.96,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Date': '2022-07-25 04:47:29',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 82.85,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 13.11,
#   'Current Description': 'light rain'},
#  {'City': 'Gornozavodsk',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:48:29',
#   'Lat': 58.3758,
#   'Lng': 58.3211,
#   'Max Temp': 72.81,
#   'Humidity': 79,
#   'Cloudiness': 63,
#   'Wind Speed': 5.28,
#   'Current Description': 'light rain'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Date': '2022-07-25 04:46:37',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 59.14,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:40:28',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 56.37,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Sanghar',
#   'Country': 'PK',
#   'Date': '2022-07-25 04:48:30',
#   'Lat': 26.0466,
#   'Lng': 68.9481,
#   'Max Temp': 87.4,
#   'Humidity': 68,
#   'Cloudiness': 85,
#   'Wind Speed': 12.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Araouane',
#   'Country': 'ML',
#   'Date': '2022-07-25 04:48:31',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 87.67,
#   'Humidity': 35,
#   'Cloudiness': 48,
#   'Wind Speed': 7.63,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Date': '2022-07-25 04:44:19',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 42.82,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iroquois Falls',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:48:32',
#   'Lat': 48.7669,
#   'Lng': -80.6831,
#   'Max Temp': 57.79,
#   'Humidity': 98,
#   'Cloudiness': 70,
#   'Wind Speed': 7.54,
#   'Current Description': 'moderate rain'},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Date': '2022-07-25 04:48:32',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 62.37,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:48:26',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 72.19,
#   'Humidity': 77,
#   'Cloudiness': 55,
#   'Wind Speed': 16.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Date': '2022-07-25 04:44:26',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.26,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:44:09',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 43.03,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Leguizamo',
#   'Country': 'CO',
#   'Date': '2022-07-25 04:48:33',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 69.8,
#   'Humidity': 96,
#   'Cloudiness': 78,
#   'Wind Speed': 1.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Date': '2022-07-25 04:48:34',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 80.69,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:44:18',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 92.77,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 1.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Date': '2022-07-25 04:46:04',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 83.61,
#   'Humidity': 78,
#   'Cloudiness': 35,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marinette',
#   'Country': 'US',
#   'Date': '2022-07-25 04:45:47',
#   'Lat': 45.1,
#   'Lng': -87.6307,
#   'Max Temp': 64.85,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Date': '2022-07-25 04:48:35',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 67.08,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Date': '2022-07-25 04:48:35',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 41.97,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 4.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Date': '2022-07-25 04:45:46',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:44:13',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 36.57,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 2.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Date': '2022-07-25 04:44:28',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 71.19,
#   'Humidity': 71,
#   'Cloudiness': 17,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Date': '2022-07-25 04:40:21',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 35.26,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:44:28',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.46,
#   'Humidity': 67,
#   'Cloudiness': 67,
#   'Wind Speed': 20.62,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:48:37',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Date': '2022-07-25 04:48:37',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 68.41,
#   'Humidity': 82,
#   'Cloudiness': 14,
#   'Wind Speed': 8.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:46:04',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 63.54,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Current Description': 'light rain'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Date': '2022-07-25 04:46:07',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 54.01,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 3.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:44:11',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 56.64,
#   'Humidity': 61,
#   'Cloudiness': 68,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Flin Flon',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:45:52',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 61.79,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:46:03',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 56.48,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 3.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Date': '2022-07-25 04:48:39',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 75.09,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jacqueville',
#   'Country': 'CI',
#   'Date': '2022-07-25 04:48:39',
#   'Lat': 5.2052,
#   'Lng': -4.4146,
#   'Max Temp': 75.87,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 6.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Date': '2022-07-25 04:48:40',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 68.31,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 7.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:48:40',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 63.01,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Raimundo Nonato',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:48:41',
#   'Lat': -9.0153,
#   'Lng': -42.6994,
#   'Max Temp': 72.05,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 9.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ko Samui',
#   'Country': 'TH',
#   'Date': '2022-07-25 04:48:41',
#   'Lat': 9.5357,
#   'Lng': 99.9357,
#   'Max Temp': 91.31,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:45:53',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 61.02,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:45:41',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 72.72,
#   'Humidity': 29,
#   'Cloudiness': 32,
#   'Wind Speed': 11.39,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Date': '2022-07-25 04:48:42',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 46.24,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Date': '2022-07-25 04:47:23',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 86.4,
#   'Humidity': 73,
#   'Cloudiness': 88,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Date': '2022-07-25 04:48:43',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 47.32,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Date': '2022-07-25 04:47:46',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 79.97,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:44:13',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 68.88,
#   'Humidity': 81,
#   'Cloudiness': 25,
#   'Wind Speed': 4.18,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Carsamba',
#   'Country': 'TR',
#   'Date': '2022-07-25 04:48:45',
#   'Lat': 41.1989,
#   'Lng': 36.7219,
#   'Max Temp': 78.3,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:48:45',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 59.52,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shenjiamen',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:49:46',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 83.17,
#   'Humidity': 82,
#   'Cloudiness': 31,
#   'Wind Speed': 7.43,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:49:46',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 44.87,
#   'Humidity': 85,
#   'Cloudiness': 83,
#   'Wind Speed': 6.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jardim',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:49:47',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 69.82,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 3.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ndele',
#   'Country': 'CF',
#   'Date': '2022-07-25 04:49:47',
#   'Lat': 8.4109,
#   'Lng': 20.6473,
#   'Max Temp': 69.39,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Date': '2022-07-25 04:48:38',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 71.53,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'thunderstorm with light rain'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Date': '2022-07-25 04:49:48',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 73.89,
#   'Humidity': 90,
#   'Cloudiness': 11,
#   'Wind Speed': 4.9,
#   'Current Description': 'few clouds'},
#  {'City': 'Karera',
#   'Country': 'IN',
#   'Date': '2022-07-25 04:49:49',
#   'Lat': 25.4667,
#   'Lng': 78.15,
#   'Max Temp': 88.07,
#   'Humidity': 62,
#   'Cloudiness': 61,
#   'Wind Speed': 11.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Plover',
#   'Country': 'US',
#   'Date': '2022-07-25 04:49:49',
#   'Lat': 44.4564,
#   'Lng': -89.544,
#   'Max Temp': 66.31,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Neryungri',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:49:50',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': 83.39,
#   'Humidity': 38,
#   'Cloudiness': 55,
#   'Wind Speed': 2.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:45:43',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 46.4,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jiayuguan',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:49:51',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 88.65,
#   'Humidity': 17,
#   'Cloudiness': 6,
#   'Wind Speed': 9.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Tateyama',
#   'Country': 'JP',
#   'Date': '2022-07-25 04:49:51',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 81.66,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:49:51',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 58.42,
#   'Humidity': 66,
#   'Cloudiness': 68,
#   'Wind Speed': 9.95,
#   'Current Description': 'light rain'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Date': '2022-07-25 04:49:52',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 62.24,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Andenes',
#   'Country': 'NO',
#   'Date': '2022-07-25 04:49:52',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 53.58,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Date': '2022-07-25 04:45:38',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.27,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:49:53',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 48.88,
#   'Humidity': 81,
#   'Cloudiness': 67,
#   'Wind Speed': 4.23,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luklukan',
#   'Country': 'PH',
#   'Date': '2022-07-25 04:49:54',
#   'Lat': 14.3254,
#   'Lng': 122.7124,
#   'Max Temp': 88.16,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 7.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Date': '2022-07-25 04:49:54',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 84.25,
#   'Humidity': 74,
#   'Cloudiness': 57,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Date': '2022-07-25 04:46:17',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 82.13,
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Current Description': 'few clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:49:55',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 68.85,
#   'Humidity': 84,
#   'Cloudiness': 94,
#   'Wind Speed': 6.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sawtell',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:49:55',
#   'Lat': -30.3833,
#   'Lng': 153.1,
#   'Max Temp': 64.42,
#   'Humidity': 63,
#   'Cloudiness': 19,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Date': '2022-07-25 04:49:56',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 72.52,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 7.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Muli',
#   'Country': 'MV',
#   'Date': '2022-07-25 04:49:56',
#   'Lat': 2.9167,
#   'Lng': 73.5667,
#   'Max Temp': 82.17,
#   'Humidity': 76,
#   'Cloudiness': 87,
#   'Wind Speed': 10.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:44:24',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 56.3,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 3.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Date': '2022-07-25 04:49:57',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 74.19,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 3.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Date': '2022-07-25 04:45:55',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 73.27,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mocuba',
#   'Country': 'MZ',
#   'Date': '2022-07-25 04:49:58',
#   'Lat': -16.8392,
#   'Lng': 36.9856,
#   'Max Temp': 62.98,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:49:58',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 61.21,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 30.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:49:59',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 77.95,
#   'Humidity': 57,
#   'Cloudiness': 95,
#   'Wind Speed': 12.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norre Alslev',
#   'Country': 'DK',
#   'Date': '2022-07-25 04:49:59',
#   'Lat': 54.8978,
#   'Lng': 11.8841,
#   'Max Temp': 67.8,
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 13.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Date': '2022-07-25 04:46:37',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 51.1,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:50:00',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 58.95,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bara',
#   'Country': 'NG',
#   'Date': '2022-07-25 04:50:01',
#   'Lat': 10.3744,
#   'Lng': 10.7288,
#   'Max Temp': 72.68,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dhandhuka',
#   'Country': 'IN',
#   'Date': '2022-07-25 04:50:01',
#   'Lat': 22.3667,
#   'Lng': 71.9833,
#   'Max Temp': 84.67,
#   'Humidity': 71,
#   'Cloudiness': 68,
#   'Wind Speed': 14.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Robertsport',
#   'Country': 'LR',
#   'Date': '2022-07-25 04:50:01',
#   'Lat': 6.7533,
#   'Lng': -11.3686,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khamamatyurt',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:50:02',
#   'Lat': 43.6081,
#   'Lng': 46.5006,
#   'Max Temp': 79.43,
#   'Humidity': 40,
#   'Cloudiness': 31,
#   'Wind Speed': 12.97,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jinchang',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:50:03',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 92.12,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:50:03',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 58.95,
#   'Humidity': 99,
#   'Cloudiness': 95,
#   'Wind Speed': 4.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Date': '2022-07-25 04:50:03',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 56.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Date': '2022-07-25 04:45:34',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 95.14,
#   'Humidity': 15,
#   'Cloudiness': 75,
#   'Wind Speed': 15.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Korem',
#   'Country': 'ET',
#   'Date': '2022-07-25 04:50:04',
#   'Lat': 12.5058,
#   'Lng': 39.5228,
#   'Max Temp': 58.17,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Macarena',
#   'Country': 'CO',
#   'Date': '2022-07-25 04:50:05',
#   'Lat': 2.1837,
#   'Lng': -73.7849,
#   'Max Temp': 70.84,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 2.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Poso',
#   'Country': 'ID',
#   'Date': '2022-07-25 04:50:05',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 87.46,
#   'Humidity': 56,
#   'Cloudiness': 36,
#   'Wind Speed': 5.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kerrville',
#   'Country': 'US',
#   'Date': '2022-07-25 04:46:35',
#   'Lat': 30.0474,
#   'Lng': -99.1403,
#   'Max Temp': 84.52,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Mantua',
#   'Country': 'IT',
#   'Date': '2022-07-25 04:50:06',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 79.84,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 3.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Fare',
#   'Country': 'PF',
#   'Date': '2022-07-25 04:50:07',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 77.29,
#   'Humidity': 82,
#   'Cloudiness': 25,
#   'Wind Speed': 12.08,
#   'Current Description': 'light rain'},
#  {'City': 'Kibala',
#   'Country': 'TD',
#   'Date': '2022-07-25 04:51:07',
#   'Lat': 9.1104,
#   'Lng': 18.3463,
#   'Max Temp': 69.75,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:46:52',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 37.36,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abatskoye',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:08',
#   'Lat': 56.2875,
#   'Lng': 70.4555,
#   'Max Temp': 70.38,
#   'Humidity': 59,
#   'Cloudiness': 21,
#   'Wind Speed': 7.56,
#   'Current Description': 'few clouds'},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:51:08',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 62.96,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bonavista',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:47:28',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 63.36,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 10.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:51:09',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 80.65,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Date': '2022-07-25 04:51:10',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 62.71,
#   'Humidity': 71,
#   'Cloudiness': 98,
#   'Wind Speed': 6.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:51:10',
#   'Lat': -0.1303,
#   'Lng': -67.0892,
#   'Max Temp': 71.65,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Solnechnyy',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:11',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 83.97,
#   'Humidity': 48,
#   'Cloudiness': 7,
#   'Wind Speed': 7.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Date': '2022-07-25 04:51:11',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 90.25,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 17.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Afua',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:51:12',
#   'Lat': -0.1567,
#   'Lng': -50.3867,
#   'Max Temp': 75.15,
#   'Humidity': 92,
#   'Cloudiness': 67,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Adeje',
#   'Country': 'ES',
#   'Date': '2022-07-25 04:51:12',
#   'Lat': 28.1227,
#   'Lng': -16.726,
#   'Max Temp': 80.17,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Nemuro',
#   'Country': 'JP',
#   'Date': '2022-07-25 04:44:19',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 65.23,
#   'Humidity': 88,
#   'Cloudiness': 22,
#   'Wind Speed': 7.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Porto Walter',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:51:13',
#   'Lat': -8.2686,
#   'Lng': -72.7439,
#   'Max Temp': 71.46,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 1.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coolum Beach',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:51:14',
#   'Lat': -26.5333,
#   'Lng': 153.1,
#   'Max Temp': 70.11,
#   'Humidity': 69,
#   'Cloudiness': 12,
#   'Wind Speed': 6.67,
#   'Current Description': 'few clouds'},
#  {'City': 'Cochabamba',
#   'Country': 'BO',
#   'Date': '2022-07-25 04:47:13',
#   'Lat': -17.3895,
#   'Lng': -66.1568,
#   'Max Temp': 58.8,
#   'Humidity': 44,
#   'Cloudiness': 16,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Date': '2022-07-25 04:51:14',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 53.46,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 17.96,
#   'Current Description': 'light rain'},
#  {'City': 'Adrano',
#   'Country': 'IT',
#   'Date': '2022-07-25 04:51:15',
#   'Lat': 37.6618,
#   'Lng': 14.8348,
#   'Max Temp': 79.23,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 5.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Usinsk',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:48:13',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 53.11,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnyy Chikoy',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:15',
#   'Lat': 50.3643,
#   'Lng': 108.7512,
#   'Max Temp': 67.75,
#   'Humidity': 70,
#   'Cloudiness': 79,
#   'Wind Speed': 4.9,
#   'Current Description': 'light rain'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Date': '2022-07-25 04:51:16',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 91.99,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:16',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 50.11,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Loubomo',
#   'Country': 'CG',
#   'Date': '2022-07-25 04:51:17',
#   'Lat': -4.1997,
#   'Lng': 12.6739,
#   'Max Temp': 68.18,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Date': '2022-07-25 04:51:17',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 85.89,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 14.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Date': '2022-07-25 04:51:18',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.86,
#   'Humidity': 72,
#   'Cloudiness': 11,
#   'Wind Speed': 7.49,
#   'Current Description': 'light rain'},
#  {'City': 'Marovoay',
#   'Country': 'MG',
#   'Date': '2022-07-25 04:51:18',
#   'Lat': -16.1,
#   'Lng': 46.6333,
#   'Max Temp': 70.72,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 6.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Date': '2022-07-25 04:51:18',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 40.8,
#   'Humidity': 79,
#   'Cloudiness': 70,
#   'Wind Speed': 7.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ketchikan',
#   'Country': 'US',
#   'Date': '2022-07-25 04:51:19',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 57.67,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'mist'},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Date': '2022-07-25 04:47:14',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 79.16,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 7.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Date': '2022-07-25 04:51:20',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 65.52,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 3.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Date': '2022-07-25 04:51:20',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 84.67,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 7.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yumen',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:51:21',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 91.69,
#   'Humidity': 15,
#   'Cloudiness': 28,
#   'Wind Speed': 15.9,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Labytnangi',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:21',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': 53.17,
#   'Humidity': 69,
#   'Cloudiness': 56,
#   'Wind Speed': 15.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Date': '2022-07-25 04:46:49',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 91.67,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port-Cartier',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:51:22',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 62.82,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Current Description': 'moderate rain'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:44:14',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.7,
#   'Humidity': 61,
#   'Cloudiness': 68,
#   'Wind Speed': 6.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:50:09',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 59.09,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'light rain'},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:51:22',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 70.47,
#   'Humidity': 84,
#   'Cloudiness': 41,
#   'Wind Speed': 13.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pampa',
#   'Country': 'US',
#   'Date': '2022-07-25 04:51:23',
#   'Lat': 35.5362,
#   'Lng': -100.9599,
#   'Max Temp': 86.2,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Tabas',
#   'Country': 'IR',
#   'Date': '2022-07-25 04:51:23',
#   'Lat': 33.5959,
#   'Lng': 56.9244,
#   'Max Temp': 100.29,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambanglipuro',
#   'Country': 'ID',
#   'Date': '2022-07-25 04:51:24',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 81.1,
#   'Humidity': 57,
#   'Cloudiness': 97,
#   'Wind Speed': 16.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Date': '2022-07-25 04:51:25',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 66.74,
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 11.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Date': '2022-07-25 04:48:08',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 95.38,
#   'Humidity': 68,
#   'Cloudiness': 11,
#   'Wind Speed': 7,
#   'Current Description': 'few clouds'},
#  {'City': 'Khasan',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:51:26',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 72.34,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 7.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Whitehorse',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:48:42',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 56.17,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santander',
#   'Country': 'ES',
#   'Date': '2022-07-25 04:51:27',
#   'Lat': 43.4647,
#   'Lng': -3.8044,
#   'Max Temp': 68.47,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Date': '2022-07-25 04:51:28',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 46.47,
#   'Humidity': 88,
#   'Cloudiness': 65,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Date': '2022-07-25 04:44:16',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 31.95,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'light rain'},
#  {'City': 'De-Kastri',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:52:29',
#   'Lat': 51.4667,
#   'Lng': 140.7833,
#   'Max Temp': 74.75,
#   'Humidity': 66,
#   'Cloudiness': 45,
#   'Wind Speed': 7.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Date': '2022-07-25 04:52:20',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.81,
#   'Humidity': 70,
#   'Cloudiness': 11,
#   'Wind Speed': 19.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Date': '2022-07-25 04:52:29',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 50.54,
#   'Humidity': 72,
#   'Cloudiness': 48,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'White Rock',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:52:30',
#   'Lat': 49.0164,
#   'Lng': -122.8026,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 81,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Anqing',
#   'Country': 'CN',
#   'Date': '2022-07-25 04:52:30',
#   'Lat': 30.5092,
#   'Lng': 117.0506,
#   'Max Temp': 98.44,
#   'Humidity': 49,
#   'Cloudiness': 50,
#   'Wind Speed': 7.92,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Date': '2022-07-25 04:52:30',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 68.05,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dhidhdhoo',
#   'Country': 'MV',
#   'Date': '2022-07-25 04:52:31',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 81.43,
#   'Humidity': 78,
#   'Cloudiness': 21,
#   'Wind Speed': 12.37,
#   'Current Description': 'few clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Date': '2022-07-25 04:52:31',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 70.88,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sharjah',
#   'Country': 'AE',
#   'Date': '2022-07-25 04:49:09',
#   'Lat': 25.3573,
#   'Lng': 55.4033,
#   'Max Temp': 100.69,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Bastia',
#   'Country': 'FR',
#   'Date': '2022-07-25 04:52:32',
#   'Lat': 42.6667,
#   'Lng': 9.3333,
#   'Max Temp': 81.3,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Popondetta',
#   'Country': 'PG',
#   'Date': '2022-07-25 04:52:33',
#   'Lat': -8.7537,
#   'Lng': 148.2534,
#   'Max Temp': 87.8,
#   'Humidity': 56,
#   'Cloudiness': 28,
#   'Wind Speed': 7.18,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Date': '2022-07-25 04:45:34',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 46.72,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.43,
#   'Current Description': 'light rain'},
#  {'City': 'Sete',
#   'Country': 'FR',
#   'Date': '2022-07-25 04:52:33',
#   'Lat': 43.4018,
#   'Lng': 3.6966,
#   'Max Temp': 75.06,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Date': '2022-07-25 04:52:34',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 62.98,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:52:34',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 70.34,
#   'Humidity': 87,
#   'Cloudiness': 51,
#   'Wind Speed': 20.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Date': '2022-07-25 04:52:35',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 53.55,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Date': '2022-07-25 04:52:35',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 55.31,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Benjamin Constant',
#   'Country': 'BR',
#   'Date': '2022-07-25 04:52:36',
#   'Lat': -4.3831,
#   'Lng': -70.0311,
#   'Max Temp': 71.73,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Date': '2022-07-25 04:52:15',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 86.34,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Suarez',
#   'Country': 'BO',
#   'Date': '2022-07-25 04:52:36',
#   'Lat': -18.95,
#   'Lng': -57.8,
# ...
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Romny',
#   'Country': 'UA',
#   'Date': '2022-07-25 05:04:59',
#   'Lat': 50.751,
#   'Lng': 33.4747,
#   'Max Temp': 63,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hof',
#   'Country': 'DE',
#   'Date': '2022-07-25 05:05:00',
#   'Lat': 50.3167,
#   'Lng': 11.9167,
#   'Max Temp': 70.5,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Kemi',
#   'Country': 'FI',
#   'Date': '2022-07-25 05:05:00',
#   'Lat': 65.8596,
#   'Lng': 24.8228,
#   'Max Temp': 58.77,
#   'Humidity': 72,
#   'Cloudiness': 91,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:05:01',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 44.91,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 12.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kurumkan',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:05:01',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 68.49,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Current Description': 'light rain'},
#  {'City': 'Barao De Melgaco',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:05:02',
#   'Lat': -16.1944,
#   'Lng': -55.9675,
#   'Max Temp': 73.2,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.16,
#   'Current Description': 'clear sky'},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Date': '2022-07-25 05:05:02',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 58.1,
#   'Humidity': 86,
#   'Cloudiness': 73,
#   'Wind Speed': 13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kattivakkam',
#   'Country': 'IN',
#   'Date': '2022-07-25 05:05:03',
#   'Lat': 13.2167,
#   'Lng': 80.3167,
#   'Max Temp': 91.49,
#   'Humidity': 71,
#   'Cloudiness': 88,
#   'Wind Speed': 7.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Phu Ly',
#   'Country': 'VN',
#   'Date': '2022-07-25 05:05:03',
#   'Lat': 20.5411,
#   'Lng': 105.9139,
#   'Max Temp': 94.08,
#   'Humidity': 50,
#   'Cloudiness': 2,
#   'Wind Speed': 5.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Date': '2022-07-25 05:00:26',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 63.05,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'mist'},
#  {'City': 'Inta',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:05:04',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': 52.3,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 15.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Devonport',
#   'Country': 'AU',
#   'Date': '2022-07-25 05:05:04',
#   'Lat': -41.1667,
#   'Lng': 146.35,
#   'Max Temp': 58.08,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 12.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beeville',
#   'Country': 'US',
#   'Date': '2022-07-25 05:05:05',
#   'Lat': 28.4008,
#   'Lng': -97.7483,
#   'Max Temp': 81.63,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Moranbah',
#   'Country': 'AU',
#   'Date': '2022-07-25 05:05:05',
#   'Lat': -22.0016,
#   'Lng': 148.0466,
#   'Max Temp': 74.66,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 8.63,
#   'Current Description': 'clear sky'},
#  {'City': 'General Roca',
#   'Country': 'AR',
#   'Date': '2022-07-25 05:05:06',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 45.63,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 13.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Quelimane',
#   'Country': 'MZ',
#   'Date': '2022-07-25 05:06:06',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 64.62,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 0.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Santo Antonio Do Ica',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:06:07',
#   'Lat': -3.1022,
#   'Lng': -67.9397,
#   'Max Temp': 71.85,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Date': '2022-07-25 05:06:08',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 63.68,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Zolotkovo',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:08',
#   'Lat': 55.5281,
#   'Lng': 41.1053,
#   'Max Temp': 75.2,
#   'Humidity': 58,
#   'Cloudiness': 25,
#   'Wind Speed': 2.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Trinidad',
#   'Country': 'BO',
#   'Date': '2022-07-25 05:06:09',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 78.08,
#   'Humidity': 50,
#   'Cloudiness': 90,
#   'Wind Speed': 3.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:05:40',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 79,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 16.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yelizovo',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:10',
#   'Lat': 53.1873,
#   'Lng': 158.3805,
#   'Max Temp': 59.14,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:10',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 69.87,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Merced',
#   'Country': 'US',
#   'Date': '2022-07-25 05:06:11',
#   'Lat': 37.1666,
#   'Lng': -120.7516,
#   'Max Temp': 80.83,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 9.37,
#   'Current Description': 'clear sky'},
#  {'City': 'Sijunjung',
#   'Country': 'ID',
#   'Date': '2022-07-25 05:06:11',
#   'Lat': -0.6876,
#   'Lng': 100.9537,
#   'Max Temp': 85.39,
#   'Humidity': 66,
#   'Cloudiness': 92,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:06:12',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 74.77,
#   'Humidity': 95,
#   'Cloudiness': 84,
#   'Wind Speed': 4.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chernoyerkovskaya',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:12',
#   'Lat': 45.4331,
#   'Lng': 37.7686,
#   'Max Temp': 77.65,
#   'Humidity': 52,
#   'Cloudiness': 31,
#   'Wind Speed': 6.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:13',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 70.25,
#   'Humidity': 44,
#   'Cloudiness': 34,
#   'Wind Speed': 5.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Date': '2022-07-25 05:06:13',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 45.45,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 7.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Etchoropo',
#   'Country': 'MX',
#   'Date': '2022-07-25 05:06:14',
#   'Lat': 26.7667,
#   'Lng': -109.6667,
#   'Max Temp': 87.42,
#   'Humidity': 67,
#   'Cloudiness': 61,
#   'Wind Speed': 11.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Almunecar',
#   'Country': 'ES',
#   'Date': '2022-07-25 05:06:15',
#   'Lat': 36.7339,
#   'Lng': -3.6907,
#   'Max Temp': 85.44,
#   'Humidity': 65,
#   'Cloudiness': 29,
#   'Wind Speed': 4.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Soe',
#   'Country': 'ID',
#   'Date': '2022-07-25 05:06:15',
#   'Lat': -9.8607,
#   'Lng': 124.284,
#   'Max Temp': 76.5,
#   'Humidity': 42,
#   'Cloudiness': 11,
#   'Wind Speed': 7.47,
#   'Current Description': 'few clouds'},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Date': '2022-07-25 05:06:16',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 56.37,
#   'Humidity': 90,
#   'Cloudiness': 61,
#   'Wind Speed': 1.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Date': '2022-07-25 05:06:16',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 62.91,
#   'Humidity': 94,
#   'Cloudiness': 59,
#   'Wind Speed': 7.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Date': '2022-07-25 05:02:35',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 80.01,
#   'Humidity': 78,
#   'Cloudiness': 81,
#   'Wind Speed': 18.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pyay',
#   'Country': 'MM',
#   'Date': '2022-07-25 05:06:17',
#   'Lat': 18.8167,
#   'Lng': 95.2167,
#   'Max Temp': 87.1,
#   'Humidity': 66,
#   'Cloudiness': 87,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chambas',
#   'Country': 'CU',
#   'Date': '2022-07-25 05:06:17',
#   'Lat': 22.1928,
#   'Lng': -78.9136,
#   'Max Temp': 76.82,
#   'Humidity': 85,
#   'Cloudiness': 8,
#   'Wind Speed': 7.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Ambilobe',
#   'Country': 'MG',
#   'Date': '2022-07-25 05:06:18',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 72.37,
#   'Humidity': 59,
#   'Cloudiness': 5,
#   'Wind Speed': 3.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Malpe',
#   'Country': 'IN',
#   'Date': '2022-07-25 05:06:19',
#   'Lat': 13.35,
#   'Lng': 74.7167,
#   'Max Temp': 83.5,
#   'Humidity': 71,
#   'Cloudiness': 94,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Smolenka',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:19',
#   'Lat': 52.1352,
#   'Lng': 113.4974,
#   'Max Temp': 64.47,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Current Description': 'moderate rain'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Date': '2022-07-25 05:06:20',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 50.02,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 2.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saquarema',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:06:20',
#   'Lat': -22.92,
#   'Lng': -42.5103,
#   'Max Temp': 66.76,
#   'Humidity': 90,
#   'Cloudiness': 53,
#   'Wind Speed': 11.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Date': '2022-07-25 05:06:22',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 72.45,
#   'Humidity': 39,
#   'Cloudiness': 62,
#   'Wind Speed': 9.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:22',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 69.03,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.09,
#   'Current Description': 'light rain'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Date': '2022-07-25 05:06:23',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 70.18,
#   'Humidity': 68,
#   'Cloudiness': 11,
#   'Wind Speed': 9.42,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Date': '2022-07-25 05:06:23',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 72.91,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Ola',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:05:38',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 68.14,
#   'Humidity': 74,
#   'Cloudiness': 96,
#   'Wind Speed': 5.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Date': '2022-07-25 05:06:24',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 52.79,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cozumel',
#   'Country': 'MX',
#   'Date': '2022-07-25 05:06:25',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 81.55,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 9.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Date': '2022-07-25 05:06:25',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 73.45,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Current Description': 'moderate rain'},
#  {'City': 'Oriximina',
#   'Country': 'BR',
#   'Date': '2022-07-25 05:06:25',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 75.88,
#   'Humidity': 77,
#   'Cloudiness': 4,
#   'Wind Speed': 3.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Kuytun',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:26',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 72.79,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Evensk',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:26',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 60.58,
#   'Humidity': 56,
#   'Cloudiness': 11,
#   'Wind Speed': 9.95,
#   'Current Description': 'few clouds'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Date': '2022-07-25 05:03:38',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 75.02,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huntington',
#   'Country': 'US',
#   'Date': '2022-07-25 05:03:45',
#   'Lat': 38.4193,
#   'Lng': -82.4452,
#   'Max Temp': 82.87,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Antigonish',
#   'Country': 'CA',
#   'Date': '2022-07-25 05:03:45',
#   'Lat': 45.6169,
#   'Lng': -61.9986,
#   'Max Temp': 67.96,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mizdah',
#   'Country': 'LY',
#   'Date': '2022-07-25 05:06:27',
#   'Lat': 31.4451,
#   'Lng': 12.9801,
#   'Max Temp': 70.86,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Wasilla',
#   'Country': 'US',
#   'Date': '2022-07-25 05:06:28',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': 67.42,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chabahar',
#   'Country': 'IR',
#   'Date': '2022-07-25 05:06:28',
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp': 84.06,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 16.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bykovo',
#   'Country': 'RU',
#   'Date': '2022-07-25 05:06:29',
#   'Lat': 55.6361,
#   'Lng': 38.0803,
#   'Max Temp': 71.33,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Cotonou',
#   'Country': 'BJ',
#   'Date': '2022-07-25 05:07:29',
#   'Lat': 6.3654,
#   'Lng': 2.4183,
#   'Max Temp': 75.92,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Obzor',
#   'Country': 'BG',
#   'Date': '2022-07-25 05:07:30',
#   'Lat': 42.8167,
#   'Lng': 27.8833,
#   'Max Temp': 73.94,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 1.74,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Date': '2022-07-25 05:07:30',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 82.18,
#   'Humidity': 78,
#   'Cloudiness': 58,
#   'Wind Speed': 4.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Llangefni',
#   'Country': 'GB',
#   'Date': '2022-07-25 05:07:31',
#   'Lat': 53.2556,
#   'Lng': -4.3106,
#   'Max Temp': 60.66,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cumana',
#   'Country': 'VE',
#   'Date': '2022-07-25 05:06:43',
#   'Lat': 10.4635,
#   'Lng': -64.1775,
#   'Max Temp': 76.78,
#   'Humidity': 85,
#   'Cloudiness': 84,
#   'Wind Speed': 9.78,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Date': '2022-07-25 05:07:32',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 83.95,
#   'Humidity': 71,
#   'Cloudiness': 30,
#   'Wind Speed': 7.67,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Date': '2022-07-25 05:07:33',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 64.49,
#   'Humidity': 86,
#   'Cloudiness': 82,
#   'Wind Speed': 9.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Windhoek',
#   'Country': 'NA',
#   'Date': '2022-07-25 05:07:33',
#   'Lat': -22.5594,
#   'Lng': 17.0832,
#   'Max Temp': 54.1,
#   'Humidity': 57,
#   'Cloudiness': 14,
#   'Wind Speed': 3.83,
#   'Current Description': 'few clouds'}]

# %%
# Check numer of cities
len(city_data)
# Out:
# 710

# %%
# Add data to a new DataFrame
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Hithadhoo      MV  2022-07-25 04:47:11  -0.6000   73.0833     82.06
# 1       Mataura      NZ  2022-07-25 04:47:12 -46.1927  168.8643     45.48
# 2       Qaanaaq      GL  2022-07-25 04:47:12  77.4840  -69.3632     37.47
# 3  Puerto Varas      CL  2022-07-25 04:47:13 -41.3195  -72.9854     43.02
# 4       Lugovoy      KZ  2022-07-25 04:47:13  42.9472   72.7644     90.32
# 5      Sobolevo      RU  2022-07-25 04:47:14  54.4299   31.8996     60.21
# 6        Kodiak      US  2022-07-25 04:47:14  57.7900 -152.4072     56.71
# 7      Hermanus      ZA  2022-07-25 04:44:26 -34.4187   19.2345     48.90
# 8  Punta Arenas      CL  2022-07-25 04:46:16 -53.1500  -70.9167     35.71
# 9        Hobart      AU  2022-07-25 04:47:15 -42.8794  147.3294     58.86
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        72          61        8.03       broken clouds
# 1        91          87        3.91     overcast clouds
# 2        99         100        4.32     overcast clouds
# 3       100         100        5.75                mist
# 4        21           0        6.60           clear sky
# 5        92          29        8.19    scattered clouds
# 6        88         100        9.22     overcast clouds
# 7        77           0       11.41           clear sky
# 8        69           0       16.11           clear sky
# 9        77          75       12.66       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
